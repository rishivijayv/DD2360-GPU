# %% [markdown]
# ### **CUDA**
# Below is an example that runs native CUDA code.
#
# 1.   We investigate the CUDA version, drivers and the avaiable GPU with nvidia-smi and nvcc-version
# 2.   We use the IPython magic command "%%writefile filename" to save a *.cu program
# 3.   We then compile and run the *.cu program with nvcc

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Tue Nov 25 09:41:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# ...

# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             46 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      2
#   On-line CPU(s) list:       0,1
# Vendor ID:                   GenuineIntel
#   Model name:                Intel(R) Xeon(R) CPU @ 2.00GHz
#     CPU family:              6
#     Model:                   85
#     Thread(s) per core:      2
#     Core(s) per socket:      1
#     Socket(s):               1
#     Stepping:                3
#     BogoMIPS:                4000.41
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ss h
#                              t syscall nx pdpe1gb rdtscp lm constant_tsc rep_goo
#                              d nopl xtopology nonstop_tsc cpuid tsc_known_freq p
# ...

# %% [markdown]
# ## Next, we write a native CUDA code and save it as 'reduction.cu'

# %%
# !which nvcc
# Out:
# /usr/local/cuda/bin/nvcc

# %% [markdown]
# ## We compile the saved cuda code using nvcc compiler

# %%
# !nvcc -arch=sm_75 reduction.cu -o reduction
# !ls
# Out:
# reduction  reduction.cu  sample_data

# %% [markdown]
# ## Finally, we execute the binary of the compiled code

# %%
# !./reduction
# Out:
# Initialise:
# 	Input length: 2**20 = 0
# 	...took: 95 ms
#
#
# Compute reference solution:
# 	Reference solution is: 0.500087
# 	...took: 4 ms
#
#
# Copy data to device:
# 	...took: 271 ms
#
#
# Launching naive kernel:
# 	Threads per Block: 1024
# 	Number of Blocks: 1024
# 	Total number of Threads: 1048576
# 	Naive solution is: 0.500086
# 	...took: 4 ms
#
#
# Launching tiling kernel:
# 	Threads per Block: 1024
# 	Number of Blocks: 1024
# 	Total number of Threads: 1048576
# 	Tiling solution is: 0.500087
# 	...took: 3 ms
#
#
# Launching tiling kernel with memory opt:
# 	Threads per Block: 1024
# 	Number of Blocks: 1
# 	Total number of Threads: 1024
# 	Elements per Thread: 1024
# 	Tiling solution is: 0.494426
# 	...took: 0 ms
#
#
# Compute reference solution:
# 	Reference solution is: 0.500087
# 	...took: 4 ms
#
#
# Copy data to device:
# 	...took: 1 ms
#
#
# Launching naive kernel:
# 	Threads per Block: 1024
# 	Number of Blocks: 1024
# 	Total number of Threads: 1048576
# ...
