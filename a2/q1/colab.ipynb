# %% [markdown]
# # Compilation

# %%
# !make
# Out:
# nvcc -arch=sm_75 -o histogram histogram.cu

# %% [markdown]
# # Testing Optimizations Against CPU

# %% [markdown]
# ## For Uniform Distribution

# %%
# !echo "Kernel 0"
# !./histogram 102400000 0 0 1 0 # Kernel 0
# !echo "Kernel 1"
# !./histogram 102400000 0 0 1 1 # Kernel 1
# !echo "Kernel 2"
# !./histogram 102400000 0 0 1 2 # Kernel 2
# Out:
# Kernel 0
# The input length is 102400000
# All results are same between GPU and CPU! :)
# CPU Time: 204.821110 ms
# GPU h-to-d time: 87.765217 ms
# GPU kernel time: 12.290955 ms
# GPU t-to-h time: 0.030041 ms
# GPU transfer and kernel time: 100.086212 ms
# Kernel 1
# The input length is 102400000
# All results are same between GPU and CPU! :)
# CPU Time: 378.595829 ms
# GPU h-to-d time: 94.969988 ms
# GPU kernel time: 153.832912 ms
# GPU t-to-h time: 0.042915 ms
# GPU transfer and kernel time: 248.845816 ms
# Kernel 2
# The input length is 102400000
# All results are same between GPU and CPU! :)
# CPU Time: 204.872131 ms
# GPU h-to-d time: 86.741924 ms
# GPU kernel time: 8.389950 ms
# GPU t-to-h time: 0.036001 ms
# GPU transfer and kernel time: 95.167875 ms

# %% [markdown]
# ## For Normal Distribution

# %%
# !echo "Kernel 0"
# !./histogram 102400000 1 0 1 0 # Kernel 0
# !echo "Kernel 1"
# !./histogram 102400000 1 0 1 1 # Kernel 1
# !echo "Kernel 2"
# !./histogram 102400000 1 0 1 2 # Kernel 2
# Out:
# Kernel 0
# The input length is 102400000
# All results are same between GPU and CPU! :)
# CPU Time: 206.622839 ms
# GPU h-to-d time: 104.830980 ms
# GPU kernel time: 13.186216 ms
# GPU t-to-h time: 0.039816 ms
# GPU transfer and kernel time: 118.057013 ms
# Kernel 1
# The input length is 102400000
# All results are same between GPU and CPU! :)
# CPU Time: 376.600981 ms
# GPU h-to-d time: 92.118025 ms
# GPU kernel time: 138.606071 ms
# GPU t-to-h time: 0.038862 ms
# GPU transfer and kernel time: 230.762959 ms
# Kernel 2
# The input length is 102400000
# All results are same between GPU and CPU! :)
# CPU Time: 383.775949 ms
# GPU h-to-d time: 93.061924 ms
# GPU kernel time: 8.436918 ms
# GPU t-to-h time: 0.036001 ms
# GPU transfer and kernel time: 101.534843 ms

# %% [markdown]
# # More Metrics to Determine Which Kernel to Use
# From the looks of it, Kernel 2 seems to be the way to go. We now use `ncu` to further ascertain that this is the right choice from our current implementations.

# %% [markdown]
# ## For Uniform Distribution

# %% [markdown]
# ### Kernel 0: No Shared Memory, Only Atomics

# %%
# !ncu ./histogram 102400000 0 0 0 0
# Out:
# The input length is 102400000
# ==PROF== Connected to process 870 (/content/histogram)
# ==PROF== Profiling "histogram_kernel_v0" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "convert_kernel" - 1: 0%....50%....100% - 9 passes
# GPU h-to-d time: 114.427090 ms
# GPU kernel time: 807.105064 ms
# GPU t-to-h time: 0.039101 ms
# GPU transfer and kernel time: 921.571255 ms
# ==PROF== Disconnected from process 870
# [870] histogram@127.0.0.1
#   histogram_kernel_v0(unsigned int *, unsigned int *, unsigned int, unsigned int) (100000, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         5.00
#     SM Frequency                    Mhz       585.00
#     Elapsed Cycles                cycle    7,063,191
#     Memory Throughput                 %        46.49
#     DRAM Throughput                   %        12.88
#     Duration                         ms        12.07
#     L1/TEX Cache Throughput           %        92.97
#     L2 Cache Throughput               %        39.95
#     SM Active Cycles              cycle 6,672,267.67
#     Compute (SM) Throughput           %        11.03
#     ----------------------- ----------- ------------
#
#     OPT   This kernel exhibits low compute throughput and memory bandwidth utilization relative to the peak performance
#           of this device. Achieved compute throughput and/or memory bandwidth below 60.0% of peak typically indicate
#           latency issues. Look at Scheduler Statistics and Warp State Statistics for potential reasons.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                100,000
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread     102,400,000
#     Uses Green Context                                             0
#     Waves Per SM                                               2,500
#     -------------------------------- --------------- ---------------
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        57.48
#     Achieved Active Warps Per SM           warp        18.39
#     ------------------------------- ----------- ------------
#
#     OPT   Est. Local Speedup: 42.52%
#           The difference between calculated theoretical (100.0%) and measured achieved occupancy (57.5%) can be the
#           result of warp scheduling overheads or workload imbalances during the kernel execution. Load imbalances can
#           occur between warps within a block as well as across blocks of the same kernel. See the CUDA Best Practices
#           Guide (https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/index.html#occupancy) for more details on
#           optimizing occupancy.
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- -------------
#     Metric Name                Metric Unit  Metric Value
#     -------------------------- ----------- -------------
#     Average DRAM Active Cycles       cycle     7,769,201
#     Total DRAM Elapsed Cycles        cycle   482,545,664
#     Average L1 Active Cycles         cycle  6,672,267.67
#     Total L1 Elapsed Cycles          cycle   282,510,696
#     Average L2 Active Cycles         cycle 10,319,877.66
#     Total L2 Elapsed Cycles          cycle   330,339,616
#     Average SM Active Cycles         cycle  6,672,267.67
#     Total SM Elapsed Cycles          cycle   282,510,696
#     Average SMSP Active Cycles       cycle  6,323,272.95
#     Total SMSP Elapsed Cycles        cycle 1,130,042,784
#     -------------------------- ----------- -------------
#
#   convert_kernel(unsigned int *, unsigned int) (4, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.84
#     SM Frequency                    Mhz       574.50
#     Elapsed Cycles                cycle        2,280
#     Memory Throughput                 %         1.80
#     DRAM Throughput                   %         1.80
#     Duration                         us         3.97
#     L1/TEX Cache Throughput           %        17.37
#     L2 Cache Throughput               %         1.67
#     SM Active Cycles              cycle       110.53
#     Compute (SM) Throughput           %         0.85
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      4
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread           4,096
#     Uses Green Context                                             0
#     Waves Per SM                                                0.10
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 90%
#           The grid for this launch is configured to execute only 4 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        93.09
#     Achieved Active Warps Per SM           warp        29.79
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          345
#     Total DRAM Elapsed Cycles        cycle      153,600
#     Average L1 Active Cycles         cycle       110.53
#     Total L1 Elapsed Cycles          cycle       90,496
#     Average L2 Active Cycles         cycle       433.59
#     Total L2 Elapsed Cycles          cycle      106,592
#     Average SM Active Cycles         cycle       110.53
#     Total SM Elapsed Cycles          cycle       90,496
#     Average SMSP Active Cycles       cycle       108.95
#     Total SMSP Elapsed Cycles        cycle      361,984
#     -------------------------- ----------- ------------
#
#     OPT   Est. Speedup: 5.581%
#           One or more L2 Slices have a much higher number of active cycles than the average number of active cycles.
#           Maximum instance value is 42.87% above the average, while the minimum instance value is 22.97% below the
#           average.

# %% [markdown]
# ### Kernel 1: Shared Memory + Atomics, 1 Thread Does More Work

# %%
# !ncu ./histogram 102400000 0 0 0 1
# Out:
# The input length is 102400000
# ==PROF== Connected to process 968 (/content/histogram)
# ==PROF== Profiling "histogram_kernel_v1" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "convert_kernel" - 1: 0%....50%....100% - 9 passes
# GPU h-to-d time: 108.314037 ms
# GPU kernel time: 1926.940918 ms
# GPU t-to-h time: 0.058889 ms
# GPU transfer and kernel time: 2035.313845 ms
# ==PROF== Disconnected from process 968
# [968] histogram@127.0.0.1
#   histogram_kernel_v1(unsigned int *, unsigned int *, unsigned int, unsigned int) (100000, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- -------------
#     Metric Name             Metric Unit  Metric Value
#     ----------------------- ----------- -------------
#     DRAM Frequency                  Ghz          5.00
#     SM Frequency                    Mhz        585.00
#     Elapsed Cycles                cycle    89,799,647
#     Memory Throughput                 %         35.46
#     DRAM Throughput                   %          1.06
#     Duration                         ms        153.50
#     L1/TEX Cache Throughput           %         35.94
#     L2 Cache Throughput               %         10.06
#     SM Active Cycles              cycle 89,356,479.10
#     Compute (SM) Throughput           %         35.46
#     ----------------------- ----------- -------------
#
#     OPT   This kernel exhibits low compute throughput and memory bandwidth utilization relative to the peak performance
#           of this device. Achieved compute throughput and/or memory bandwidth below 60.0% of peak typically indicate
#           latency issues. Look at Scheduler Statistics and Warp State Statistics for potential reasons.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                100,000
#     Registers Per Thread             register/thread              36
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block       Kbyte/block           16.38
#     # SMs                                         SM              40
#     Threads                                   thread     102,400,000
#     Uses Green Context                                             0
#     Waves Per SM                                               2,500
#     -------------------------------- --------------- ---------------
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            1
#     Block Limit Shared Mem                block            2
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        16.24
#     Achieved Active Warps Per SM           warp         5.20
#     ------------------------------- ----------- ------------
#
#     OPT   Est. Local Speedup: 83.76%
#           The difference between calculated theoretical (100.0%) and measured achieved occupancy (16.2%) can be the
#           result of warp scheduling overheads or workload imbalances during the kernel execution. Load imbalances can
#           occur between warps within a block as well as across blocks of the same kernel. See the CUDA Best Practices
#           Guide (https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/index.html#occupancy) for more details on
#           optimizing occupancy.
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- --------------
#     Metric Name                Metric Unit   Metric Value
#     -------------------------- ----------- --------------
#     Average DRAM Active Cycles       cycle      8,114,997
#     Total DRAM Elapsed Cycles        cycle  6,135,275,520
#     Average L1 Active Cycles         cycle  89,356,479.10
#     Total L1 Elapsed Cycles          cycle  3,592,011,888
#     Average L2 Active Cycles         cycle  45,360,924.19
#     Total L2 Elapsed Cycles          cycle  4,199,859,712
#     Average SM Active Cycles         cycle  89,356,479.10
#     Total SM Elapsed Cycles          cycle  3,592,011,888
#     Average SMSP Active Cycles       cycle  31,440,973.08
#     Total SMSP Elapsed Cycles        cycle 14,368,047,552
#     -------------------------- ----------- --------------
#
#   convert_kernel(unsigned int *, unsigned int) (4, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.68
#     SM Frequency                    Mhz       570.43
#     Elapsed Cycles                cycle        2,374
#     Memory Throughput                 %         1.75
#     DRAM Throughput                   %         1.75
#     Duration                         us         4.16
#     L1/TEX Cache Throughput           %        17.59
#     L2 Cache Throughput               %         1.63
#     SM Active Cycles              cycle       109.17
#     Compute (SM) Throughput           %         0.85
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      4
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread           4,096
#     Uses Green Context                                             0
#     Waves Per SM                                                0.10
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 90%
#           The grid for this launch is configured to execute only 4 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        98.93
#     Achieved Active Warps Per SM           warp        31.66
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          341
#     Total DRAM Elapsed Cycles        cycle      155,648
#     Average L1 Active Cycles         cycle       109.17
#     Total L1 Elapsed Cycles          cycle       90,880
#     Average L2 Active Cycles         cycle       427.41
#     Total L2 Elapsed Cycles          cycle      110,976
#     Average SM Active Cycles         cycle       109.17
#     Total SM Elapsed Cycles          cycle       90,880
#     Average SMSP Active Cycles       cycle       108.25
#     Total SMSP Elapsed Cycles        cycle      363,520
#     -------------------------- ----------- ------------

# %% [markdown]
# ### Kernel 2: Shared Memory + Atomics, Threads Do Similar Amount of Work

# %%
# !ncu ./histogram 102400000 0 0 0 2
# Out:
# The input length is 102400000
# ==PROF== Connected to process 1068 (/content/histogram)
# ==PROF== Profiling "histogram_kernel_v2" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "convert_kernel" - 1: 0%....50%....100% - 9 passes
# GPU h-to-d time: 112.285852 ms
# GPU kernel time: 640.719891 ms
# GPU t-to-h time: 0.040054 ms
# GPU transfer and kernel time: 753.045797 ms
# ==PROF== Disconnected from process 1068
# [1068] histogram@127.0.0.1
#   histogram_kernel_v2(unsigned int *, unsigned int *, unsigned int, unsigned int) (100000, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         5.00
#     SM Frequency                    Mhz       585.00
#     Elapsed Cycles                cycle    4,778,803
#     Memory Throughput                 %        50.20
#     DRAM Throughput                   %        19.98
#     Duration                         ms         8.17
#     L1/TEX Cache Throughput           %        68.61
#     L2 Cache Throughput               %        29.67
#     SM Active Cycles              cycle 4,390,471.08
#     Compute (SM) Throughput           %        50.20
#     ----------------------- ----------- ------------
#
#     OPT   This kernel exhibits low compute throughput and memory bandwidth utilization relative to the peak performance
#           of this device. Achieved compute throughput and/or memory bandwidth below 60.0% of peak typically indicate
#           latency issues. Look at Scheduler Statistics and Warp State Statistics for potential reasons.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                100,000
#     Registers Per Thread             register/thread              22
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block       Kbyte/block           16.38
#     # SMs                                         SM              40
#     Threads                                   thread     102,400,000
#     Uses Green Context                                             0
#     Waves Per SM                                               2,500
#     -------------------------------- --------------- ---------------
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            2
#     Block Limit Shared Mem                block            2
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        88.63
#     Achieved Active Warps Per SM           warp        28.36
#     ------------------------------- ----------- ------------
#
#     OPT   Est. Local Speedup: 11.37%
#           The difference between calculated theoretical (100.0%) and measured achieved occupancy (88.6%) can be the
#           result of warp scheduling overheads or workload imbalances during the kernel execution. Load imbalances can
#           occur between warps within a block as well as across blocks of the same kernel. See the CUDA Best Practices
#           Guide (https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/index.html#occupancy) for more details on
#           optimizing occupancy.
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle 8,156,156.50
#     Total DRAM Elapsed Cycles        cycle  326,558,720
#     Average L1 Active Cycles         cycle 4,390,471.08
#     Total L1 Elapsed Cycles          cycle  191,227,944
#     Average L2 Active Cycles         cycle 6,665,658.75
#     Total L2 Elapsed Cycles          cycle  223,500,640
#     Average SM Active Cycles         cycle 4,390,471.08
#     Total SM Elapsed Cycles          cycle  191,227,944
#     Average SMSP Active Cycles       cycle 4,312,885.89
#     Total SMSP Elapsed Cycles        cycle  764,911,776
#     -------------------------- ----------- ------------
#
#   convert_kernel(unsigned int *, unsigned int) (4, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.83
#     SM Frequency                    Mhz       571.88
#     Elapsed Cycles                cycle        2,306
#     Memory Throughput                 %         1.78
#     DRAM Throughput                   %         1.78
#     Duration                         us         4.03
#     L1/TEX Cache Throughput           %        17.56
#     L2 Cache Throughput               %         1.65
#     SM Active Cycles              cycle       109.33
#     Compute (SM) Throughput           %         0.85
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      4
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread           4,096
#     Uses Green Context                                             0
#     Waves Per SM                                                0.10
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 90%
#           The grid for this launch is configured to execute only 4 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        95.25
#     Achieved Active Warps Per SM           warp        30.48
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          346
#     Total DRAM Elapsed Cycles        cycle      155,648
#     Average L1 Active Cycles         cycle       109.33
#     Total L1 Elapsed Cycles          cycle       90,272
#     Average L2 Active Cycles         cycle       431.72
#     Total L2 Elapsed Cycles          cycle      107,840
#     Average SM Active Cycles         cycle       109.33
#     Total SM Elapsed Cycles          cycle       90,272
#     Average SMSP Active Cycles       cycle       107.19
#     Total SMSP Elapsed Cycles        cycle      361,088
#     -------------------------- ----------- ------------

# %% [markdown]
# ## For Normal Distribution

# %% [markdown]
# ### Kernel 0: No Shared Memory, Only Atomics

# %%
# !ncu ./histogram 102400000 1 0 0 0
# Out:
# The input length is 102400000
# ==PROF== Connected to process 1162 (/content/histogram)
# ==PROF== Profiling "histogram_kernel_v0" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "convert_kernel" - 1: 0%....50%....100% - 9 passes
# GPU h-to-d time: 108.165979 ms
# GPU kernel time: 559.966087 ms
# GPU t-to-h time: 0.038862 ms
# GPU transfer and kernel time: 668.170929 ms
# ==PROF== Disconnected from process 1162
# [1162] histogram@127.0.0.1
#   histogram_kernel_v0(unsigned int *, unsigned int *, unsigned int, unsigned int) (100000, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.99
#     SM Frequency                    Mhz       585.00
#     Elapsed Cycles                cycle    7,575,156
#     Memory Throughput                 %        46.08
#     DRAM Throughput                   %        12.05
#     Duration                         ms        12.95
#     L1/TEX Cache Throughput           %        92.16
#     L2 Cache Throughput               %        39.62
#     SM Active Cycles              cycle 7,183,121.08
#     Compute (SM) Throughput           %         9.53
#     ----------------------- ----------- ------------
#
#     OPT   This kernel exhibits low compute throughput and memory bandwidth utilization relative to the peak performance
#           of this device. Achieved compute throughput and/or memory bandwidth below 60.0% of peak typically indicate
#           latency issues. Look at Scheduler Statistics and Warp State Statistics for potential reasons.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                100,000
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread     102,400,000
#     Uses Green Context                                             0
#     Waves Per SM                                               2,500
#     -------------------------------- --------------- ---------------
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        56.87
#     Achieved Active Warps Per SM           warp        18.20
#     ------------------------------- ----------- ------------
#
#     OPT   Est. Local Speedup: 43.13%
#           The difference between calculated theoretical (100.0%) and measured achieved occupancy (56.9%) can be the
#           result of warp scheduling overheads or workload imbalances during the kernel execution. Load imbalances can
#           occur between warps within a block as well as across blocks of the same kernel. See the CUDA Best Practices
#           Guide (https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/index.html#occupancy) for more details on
#           optimizing occupancy.
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- -------------
#     Metric Name                Metric Unit  Metric Value
#     -------------------------- ----------- -------------
#     Average DRAM Active Cycles       cycle     7,790,500
#     Total DRAM Elapsed Cycles        cycle   517,408,768
#     Average L1 Active Cycles         cycle  7,183,121.08
#     Total L1 Elapsed Cycles          cycle   303,435,464
#     Average L2 Active Cycles         cycle 10,677,385.44
#     Total L2 Elapsed Cycles          cycle   354,283,680
#     Average SM Active Cycles         cycle  7,183,121.08
#     Total SM Elapsed Cycles          cycle   303,435,464
#     Average SMSP Active Cycles       cycle  6,859,611.40
#     Total SMSP Elapsed Cycles        cycle 1,213,741,856
#     -------------------------- ----------- -------------
#
#   convert_kernel(unsigned int *, unsigned int) (4, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.83
#     SM Frequency                    Mhz       570.59
#     Elapsed Cycles                cycle        2,301
#     Memory Throughput                 %         1.75
#     DRAM Throughput                   %         1.75
#     Duration                         us         4.03
#     L1/TEX Cache Throughput           %        17.35
#     L2 Cache Throughput               %         1.68
#     SM Active Cycles              cycle       110.65
#     Compute (SM) Throughput           %         0.85
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      4
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread           4,096
#     Uses Green Context                                             0
#     Waves Per SM                                                0.10
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 90%
#           The grid for this launch is configured to execute only 4 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        93.87
#     Achieved Active Warps Per SM           warp        30.04
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          341
#     Total DRAM Elapsed Cycles        cycle      155,648
#     Average L1 Active Cycles         cycle       110.65
#     Total L1 Elapsed Cycles          cycle       90,488
#     Average L2 Active Cycles         cycle       432.81
#     Total L2 Elapsed Cycles          cycle      107,616
#     Average SM Active Cycles         cycle       110.65
#     Total SM Elapsed Cycles          cycle       90,488
#     Average SMSP Active Cycles       cycle       107.01
#     Total SMSP Elapsed Cycles        cycle      361,952
#     -------------------------- ----------- ------------

# %% [markdown]
# ### Kernel 1: Shared Memory + Atomics, 1 Thread Does More Work

# %%
# !ncu ./histogram 102400000 1 0 0 1
# Out:
# The input length is 102400000
# ==PROF== Connected to process 1292 (/content/histogram)
# ==PROF== Profiling "histogram_kernel_v1" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "convert_kernel" - 1: 0%....50%....100% - 9 passes
# GPU h-to-d time: 114.621878 ms
# GPU kernel time: 1886.146069 ms
# GPU t-to-h time: 0.036955 ms
# GPU transfer and kernel time: 2000.804901 ms
# ==PROF== Disconnected from process 1292
# [1292] histogram@127.0.0.1
#   histogram_kernel_v1(unsigned int *, unsigned int *, unsigned int, unsigned int) (100000, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- -------------
#     Metric Name             Metric Unit  Metric Value
#     ----------------------- ----------- -------------
#     DRAM Frequency                  Ghz          5.00
#     SM Frequency                    Mhz        585.00
#     Elapsed Cycles                cycle    89,796,792
#     Memory Throughput                 %         35.46
#     DRAM Throughput                   %          1.06
#     Duration                         ms        153.50
#     L1/TEX Cache Throughput           %         35.94
#     L2 Cache Throughput               %         10.06
#     SM Active Cycles              cycle 89,348,150.33
#     Compute (SM) Throughput           %         35.46
#     ----------------------- ----------- -------------
#
#     OPT   This kernel exhibits low compute throughput and memory bandwidth utilization relative to the peak performance
#           of this device. Achieved compute throughput and/or memory bandwidth below 60.0% of peak typically indicate
#           latency issues. Look at Scheduler Statistics and Warp State Statistics for potential reasons.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                100,000
#     Registers Per Thread             register/thread              36
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block       Kbyte/block           16.38
#     # SMs                                         SM              40
#     Threads                                   thread     102,400,000
#     Uses Green Context                                             0
#     Waves Per SM                                               2,500
#     -------------------------------- --------------- ---------------
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            1
#     Block Limit Shared Mem                block            2
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        16.24
#     Achieved Active Warps Per SM           warp         5.20
#     ------------------------------- ----------- ------------
#
#     OPT   Est. Local Speedup: 83.76%
#           The difference between calculated theoretical (100.0%) and measured achieved occupancy (16.2%) can be the
#           result of warp scheduling overheads or workload imbalances during the kernel execution. Load imbalances can
#           occur between warps within a block as well as across blocks of the same kernel. See the CUDA Best Practices
#           Guide (https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/index.html#occupancy) for more details on
#           optimizing occupancy.
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- --------------
#     Metric Name                Metric Unit   Metric Value
#     -------------------------- ----------- --------------
#     Average DRAM Active Cycles       cycle   8,121,905.50
#     Total DRAM Elapsed Cycles        cycle  6,135,140,352
#     Average L1 Active Cycles         cycle  89,348,150.33
#     Total L1 Elapsed Cycles          cycle  3,592,008,960
#     Average L2 Active Cycles         cycle  45,229,834.56
#     Total L2 Elapsed Cycles          cycle  4,199,726,432
#     Average SM Active Cycles         cycle  89,348,150.33
#     Total SM Elapsed Cycles          cycle  3,592,008,960
#     Average SMSP Active Cycles       cycle  31,440,618.79
#     Total SMSP Elapsed Cycles        cycle 14,368,035,840
#     -------------------------- ----------- --------------
#
#   convert_kernel(unsigned int *, unsigned int) (4, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.83
#     SM Frequency                    Mhz       576.15
#     Elapsed Cycles                cycle        2,305
#     Memory Throughput                 %         1.79
#     DRAM Throughput                   %         1.79
#     Duration                         us            4
#     L1/TEX Cache Throughput           %        17.58
#     L2 Cache Throughput               %         1.65
#     SM Active Cycles              cycle       109.20
#     Compute (SM) Throughput           %         0.85
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      4
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread           4,096
#     Uses Green Context                                             0
#     Waves Per SM                                                0.10
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 90%
#           The grid for this launch is configured to execute only 4 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        95.28
#     Achieved Active Warps Per SM           warp        30.49
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          346
#     Total DRAM Elapsed Cycles        cycle      154,624
#     Average L1 Active Cycles         cycle       109.20
#     Total L1 Elapsed Cycles          cycle       90,632
#     Average L2 Active Cycles         cycle       437.66
#     Total L2 Elapsed Cycles          cycle      107,808
#     Average SM Active Cycles         cycle       109.20
#     Total SM Elapsed Cycles          cycle       90,632
#     Average SMSP Active Cycles       cycle       106.89
#     Total SMSP Elapsed Cycles        cycle      362,528
#     -------------------------- ----------- ------------
#
#     OPT   Est. Speedup: 5.954%
#           One or more L2 Slices have a much higher number of active cycles than the average number of active cycles.
#           Maximum instance value is 45.83% above the average, while the minimum instance value is 21.17% below the
#           average.

# %% [markdown]
# ### Kernel 2: Shared Memory + Atomics, Threads Do Similar Amount of Work

# %%
# !ncu ./histogram 102400000 1 0 0 2
# Out:
# The input length is 102400000
# ==PROF== Connected to process 1412 (/content/histogram)
# ==PROF== Profiling "histogram_kernel_v2" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "convert_kernel" - 1: 0%....50%....100% - 9 passes
# GPU h-to-d time: 97.759008 ms
# GPU kernel time: 532.022953 ms
# GPU t-to-h time: 0.044107 ms
# GPU transfer and kernel time: 629.826069 ms
# ==PROF== Disconnected from process 1412
# [1412] histogram@127.0.0.1
#   histogram_kernel_v2(unsigned int *, unsigned int *, unsigned int, unsigned int) (100000, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         5.00
#     SM Frequency                    Mhz       585.00
#     Elapsed Cycles                cycle    4,777,769
#     Memory Throughput                 %        50.26
#     DRAM Throughput                   %        19.98
#     Duration                         ms         8.17
#     L1/TEX Cache Throughput           %        68.68
#     L2 Cache Throughput               %        29.67
#     SM Active Cycles              cycle 4,388,378.03
#     Compute (SM) Throughput           %        50.26
#     ----------------------- ----------- ------------
#
#     OPT   This kernel exhibits low compute throughput and memory bandwidth utilization relative to the peak performance
#           of this device. Achieved compute throughput and/or memory bandwidth below 60.0% of peak typically indicate
#           latency issues. Look at Scheduler Statistics and Warp State Statistics for potential reasons.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                100,000
#     Registers Per Thread             register/thread              22
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block       Kbyte/block           16.38
#     # SMs                                         SM              40
#     Threads                                   thread     102,400,000
#     Uses Green Context                                             0
#     Waves Per SM                                               2,500
#     -------------------------------- --------------- ---------------
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            2
#     Block Limit Shared Mem                block            2
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        88.66
#     Achieved Active Warps Per SM           warp        28.37
#     ------------------------------- ----------- ------------
#
#     OPT   Est. Local Speedup: 11.34%
#           The difference between calculated theoretical (100.0%) and measured achieved occupancy (88.7%) can be the
#           result of warp scheduling overheads or workload imbalances during the kernel execution. Load imbalances can
#           occur between warps within a block as well as across blocks of the same kernel. See the CUDA Best Practices
#           Guide (https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/index.html#occupancy) for more details on
#           optimizing occupancy.
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle 8,152,685.50
#     Total DRAM Elapsed Cycles        cycle  326,486,016
#     Average L1 Active Cycles         cycle 4,388,378.03
#     Total L1 Elapsed Cycles          cycle  191,021,040
#     Average L2 Active Cycles         cycle 6,669,271.41
#     Total L2 Elapsed Cycles          cycle  223,452,384
#     Average SM Active Cycles         cycle 4,388,378.03
#     Total SM Elapsed Cycles          cycle  191,021,040
#     Average SMSP Active Cycles       cycle 4,313,165.24
#     Total SMSP Elapsed Cycles        cycle  764,084,160
#     -------------------------- ----------- ------------
#
#   convert_kernel(unsigned int *, unsigned int) (4, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.80
#     SM Frequency                    Mhz       575.40
#     Elapsed Cycles                cycle        2,302
#     Memory Throughput                 %         1.77
#     DRAM Throughput                   %         1.77
#     Duration                         us            4
#     L1/TEX Cache Throughput           %        17.63
#     L2 Cache Throughput               %         1.68
#     SM Active Cycles              cycle       108.90
#     Compute (SM) Throughput           %         0.84
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      4
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread           4,096
#     Uses Green Context                                             0
#     Waves Per SM                                                0.10
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 90%
#           The grid for this launch is configured to execute only 4 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        95.81
#     Achieved Active Warps Per SM           warp        30.66
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          340
#     Total DRAM Elapsed Cycles        cycle      153,600
#     Average L1 Active Cycles         cycle       108.90
#     Total L1 Elapsed Cycles          cycle       91,080
#     Average L2 Active Cycles         cycle       432.38
#     Total L2 Elapsed Cycles          cycle      107,584
#     Average SM Active Cycles         cycle       108.90
#     Total SM Elapsed Cycles          cycle       91,080
#     Average SMSP Active Cycles       cycle       106.64
#     Total SMSP Elapsed Cycles        cycle      364,320
#     -------------------------- ----------- ------------

# %% [markdown]
# # Histogram Graphs
# We compare the GPU and the CPU histograms for the specified sizes and then generate the results in the text file, which are then graphed. `generate_results.py` first generates the results for us. The `*.txt` files generated (included in the submitted code) can then be plotted using `python3 plot_histogram.py`

# %% [markdown]
# ## Generating the Results

# %%
# !python3 generate_results.py
# Out:
# Generating Graphs for UNIFORM distribution
# Current N=1024
# Running: ./histogram 1024 0 1 1 2
# The input length is 1024
# All results are same between GPU and CPU! :)
# Saved Histogram!
# CPU Time: 0.004053 ms
# GPU h-to-d time: 1.283884 ms
# GPU kernel time: 0.213861 ms
# GPU t-to-h time: 0.038147 ms
# GPU transfer and kernel time: 1.535892 ms
#
# -----------------------------------
# Current N=10240
# Running: ./histogram 10240 0 1 1 2
# The input length is 10240
# All results are same between GPU and CPU! :)
# Saved Histogram!
# CPU Time: 0.041008 ms
# GPU h-to-d time: 0.054121 ms
# GPU kernel time: 0.197887 ms
# GPU t-to-h time: 0.028133 ms
# GPU transfer and kernel time: 0.280142 ms
#
# -----------------------------------
# Current N=102400
# Running: ./histogram 102400 0 1 1 2
# The input length is 102400
# All results are same between GPU and CPU! :)
# Saved Histogram!
# CPU Time: 0.425100 ms
# GPU h-to-d time: 0.141144 ms
# GPU kernel time: 0.197887 ms
# GPU t-to-h time: 0.029087 ms
# GPU transfer and kernel time: 0.368118 ms
#
# -----------------------------------
# Current N=1024000
# Running: ./histogram 1024000 0 1 1 2
# The input length is 1024000
# All results are same between GPU and CPU! :)
# Saved Histogram!
# CPU Time: 4.118919 ms
# GPU h-to-d time: 1.037121 ms
# GPU kernel time: 0.285864 ms
# GPU t-to-h time: 0.029087 ms
# GPU transfer and kernel time: 1.352072 ms
#
# -----------------------------------
# ------------------------------
# Generating Graphs for NORMAL distribution
# Current N=1024
# Running: ./histogram 1024 1 1 1 2
# The input length is 1024
# All results are same between GPU and CPU! :)
# Saved Histogram!
# CPU Time: 0.007868 ms
# GPU h-to-d time: 0.039816 ms
# GPU kernel time: 0.174046 ms
# GPU t-to-h time: 0.029087 ms
# GPU transfer and kernel time: 0.242949 ms
#
# -----------------------------------
# Current N=10240
# Running: ./histogram 10240 1 1 1 2
# The input length is 10240
# All results are same between GPU and CPU! :)
# Saved Histogram!
# CPU Time: 0.040054 ms
# GPU h-to-d time: 0.049114 ms
# GPU kernel time: 0.162840 ms
# GPU t-to-h time: 0.029087 ms
# GPU transfer and kernel time: 0.241041 ms
#
# -----------------------------------
# Current N=102400
# Running: ./histogram 102400 1 1 1 2
# The input length is 102400
# All results are same between GPU and CPU! :)
# Saved Histogram!
# CPU Time: 0.406981 ms
# GPU h-to-d time: 0.128984 ms
# GPU kernel time: 0.187874 ms
# GPU t-to-h time: 0.051022 ms
# GPU transfer and kernel time: 0.367880 ms
#
# -----------------------------------
# Current N=1024000
# Running: ./histogram 1024000 1 1 1 2
# The input length is 1024000
# All results are same between GPU and CPU! :)
# Saved Histogram!
# CPU Time: 5.465984 ms
# GPU h-to-d time: 1.044989 ms
# GPU kernel time: 0.277042 ms
# GPU t-to-h time: 0.028849 ms
# GPU transfer and kernel time: 1.350880 ms
#
# -----------------------------------
# ------------------------------

# %% [markdown]
# # Shared Memory and Occupancy for N=1024
# We profile for both Uniform and Normal distribution.

# %%
# !ncu ./histogram 1024 0 0 0 2
# Out:
# The input length is 1024
# ==PROF== Connected to process 1847 (/content/histogram)
# ==PROF== Profiling "histogram_kernel_v2" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "convert_kernel" - 1: 0%....50%....100% - 9 passes
# GPU h-to-d time: 1.667023 ms
# GPU kernel time: 560.741901 ms
# GPU t-to-h time: 0.031233 ms
# GPU transfer and kernel time: 562.440157 ms
# ==PROF== Disconnected from process 1847
# [1847] histogram@127.0.0.1
#   histogram_kernel_v2(unsigned int *, unsigned int *, unsigned int, unsigned int) (1, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.84
#     SM Frequency                    Mhz       575.76
#     Elapsed Cycles                cycle        3,354
#     Memory Throughput                 %         1.79
#     DRAM Throughput                   %         1.79
#     Duration                         us         5.82
#     L1/TEX Cache Throughput           %        44.47
#     L2 Cache Throughput               %         0.91
#     SM Active Cycles              cycle        53.98
#     Compute (SM) Throughput           %         0.72
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.0 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      1
#     Registers Per Thread             register/thread              22
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block       Kbyte/block           16.38
#     # SMs                                         SM              40
#     Threads                                   thread           1,024
#     Uses Green Context                                             0
#     Waves Per SM                                                0.03
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 97.5%
#           The grid for this launch is configured to execute only 1 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            2
#     Block Limit Shared Mem                block            2
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        92.77
#     Achieved Active Warps Per SM           warp        29.69
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          503
#     Total DRAM Elapsed Cycles        cycle      225,280
#     Average L1 Active Cycles         cycle        53.98
#     Total L1 Elapsed Cycles          cycle      132,424
#     Average L2 Active Cycles         cycle       705.62
#     Total L2 Elapsed Cycles          cycle      156,832
#     Average SM Active Cycles         cycle        53.98
#     Total SM Elapsed Cycles          cycle      132,424
#     Average SMSP Active Cycles       cycle        53.33
#     Total SMSP Elapsed Cycles        cycle      529,696
#     -------------------------- ----------- ------------
#
#     OPT   Est. Speedup: 5.179%
#           One or more L2 Slices have a much higher number of active cycles than the average number of active cycles.
#           Additionally, other L2 Slices have a much lower number of active cycles than the average number of active
#           cycles. Maximum instance value is 35.97% above the average, while the minimum instance value is 37.79% below
#           the average.
#
#   convert_kernel(unsigned int *, unsigned int) (4, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.74
#     SM Frequency                    Mhz       576.50
#     Elapsed Cycles                cycle        2,307
#     Memory Throughput                 %         1.82
#     DRAM Throughput                   %         1.82
#     Duration                         us            4
#     L1/TEX Cache Throughput           %        12.04
#     L2 Cache Throughput               %         1.18
#     SM Active Cycles              cycle       106.35
#     Compute (SM) Throughput           %         0.57
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      4
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread           4,096
#     Uses Green Context                                             0
#     Waves Per SM                                                0.10
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 90%
#           The grid for this launch is configured to execute only 4 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        98.79
#     Achieved Active Warps Per SM           warp        31.61
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          345
#     Total DRAM Elapsed Cycles        cycle      151,552
#     Average L1 Active Cycles         cycle       106.35
#     Total L1 Elapsed Cycles          cycle       89,496
#     Average L2 Active Cycles         cycle       368.50
#     Total L2 Elapsed Cycles          cycle      107,840
#     Average SM Active Cycles         cycle       106.35
#     Total SM Elapsed Cycles          cycle       89,496
#     Average SMSP Active Cycles       cycle       102.72
#     Total SMSP Elapsed Cycles        cycle      357,984
#     -------------------------- ----------- ------------

# %%
# !ncu ./histogram 1024 1 0 0 2
# Out:
# The input length is 1024
# ==PROF== Connected to process 1911 (/content/histogram)
# ==PROF== Profiling "histogram_kernel_v2" - 0: 0%....50%....100% - 9 passes
# ==PROF== Profiling "convert_kernel" - 1: 0%....50%....100% - 9 passes
# GPU h-to-d time: 0.061989 ms
# GPU kernel time: 406.075954 ms
# GPU t-to-h time: 0.036001 ms
# GPU transfer and kernel time: 406.173944 ms
# ==PROF== Disconnected from process 1911
# [1911] histogram@127.0.0.1
#   histogram_kernel_v2(unsigned int *, unsigned int *, unsigned int, unsigned int) (1, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.88
#     SM Frequency                    Mhz       580.94
#     Elapsed Cycles                cycle        3,384
#     Memory Throughput                 %         1.79
#     DRAM Throughput                   %         1.79
#     Duration                         us         5.82
#     L1/TEX Cache Throughput           %        43.96
#     L2 Cache Throughput               %         0.90
#     SM Active Cycles              cycle        54.60
#     Compute (SM) Throughput           %         0.73
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.0 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      1
#     Registers Per Thread             register/thread              22
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block       Kbyte/block           16.38
#     # SMs                                         SM              40
#     Threads                                   thread           1,024
#     Uses Green Context                                             0
#     Waves Per SM                                                0.03
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 97.5%
#           The grid for this launch is configured to execute only 1 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            2
#     Block Limit Shared Mem                block            2
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        91.35
#     Achieved Active Warps Per SM           warp        29.23
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          509
#     Total DRAM Elapsed Cycles        cycle      227,328
#     Average L1 Active Cycles         cycle        54.60
#     Total L1 Elapsed Cycles          cycle      132,368
#     Average L2 Active Cycles         cycle       658.66
#     Total L2 Elapsed Cycles          cycle      158,272
#     Average SM Active Cycles         cycle        54.60
#     Total SM Elapsed Cycles          cycle      132,368
#     Average SMSP Active Cycles       cycle        53.80
#     Total SMSP Elapsed Cycles        cycle      529,472
#     -------------------------- ----------- ------------
#
#     OPT   Est. Speedup: 5.436%
#           One or more L2 Slices have a much lower number of active cycles than the average number of active cycles.
#           Maximum instance value is 40.82% above the average, while the minimum instance value is 45.50% below the
#           average.
#
#   convert_kernel(unsigned int *, unsigned int) (4, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.81
#     SM Frequency                    Mhz       575.15
#     Elapsed Cycles                cycle        2,264
#     Memory Throughput                 %         1.81
#     DRAM Throughput                   %         1.81
#     Duration                         us         3.94
#     L1/TEX Cache Throughput           %        12.07
#     L2 Cache Throughput               %         1.23
#     SM Active Cycles              cycle       106.05
#     Compute (SM) Throughput           %         0.58
#     ----------------------- ----------- ------------
#
#     OPT   This kernel grid is too small to fill the available resources on this device, resulting in only 0.1 full
#           waves across all SMs. Look at Launch Statistics for more details.
#
#     Section: Launch Statistics
#     -------------------------------- --------------- ---------------
#     Metric Name                          Metric Unit    Metric Value
#     -------------------------------- --------------- ---------------
#     Block Size                                                 1,024
#     Function Cache Configuration                     CachePreferNone
#     Grid Size                                                      4
#     Registers Per Thread             register/thread              16
#     Shared Memory Configuration Size           Kbyte           32.77
#     Driver Shared Memory Per Block        byte/block               0
#     Dynamic Shared Memory Per Block       byte/block               0
#     Static Shared Memory Per Block        byte/block               0
#     # SMs                                         SM              40
#     Threads                                   thread           4,096
#     Uses Green Context                                             0
#     Waves Per SM                                                0.10
#     -------------------------------- --------------- ---------------
#
#     OPT   Est. Speedup: 90%
#           The grid for this launch is configured to execute only 4 blocks, which is less than the GPU's 40
#           multiprocessors. This can underutilize some multiprocessors. If you do not intend to execute this kernel
#           concurrently with other workloads, consider reducing the block size to have at least one block per
#           multiprocessor or increase the size of the grid to fully utilize the available hardware resources. See the
#           Hardware Model (https://docs.nvidia.com/nsight-compute/ProfilingGuide/index.html#metrics-hw-model)
#           description for more details on launch configurations.
#
#     Section: Occupancy
#     ------------------------------- ----------- ------------
#     Metric Name                     Metric Unit Metric Value
#     ------------------------------- ----------- ------------
#     Block Limit SM                        block           16
#     Block Limit Registers                 block            4
#     Block Limit Shared Mem                block           16
#     Block Limit Warps                     block            1
#     Theoretical Active Warps per SM        warp           32
#     Theoretical Occupancy                     %          100
#     Achieved Occupancy                        %        95.54
#     Achieved Active Warps Per SM           warp        30.57
#     ------------------------------- ----------- ------------
#
#     Section: GPU and Memory Workload Distribution
#     -------------------------- ----------- ------------
#     Metric Name                Metric Unit Metric Value
#     -------------------------- ----------- ------------
#     Average DRAM Active Cycles       cycle          343
#     Total DRAM Elapsed Cycles        cycle      151,552
#     Average L1 Active Cycles         cycle       106.05
#     Total L1 Elapsed Cycles          cycle       88,920
#     Average L2 Active Cycles         cycle       364.84
#     Total L2 Elapsed Cycles          cycle      105,856
#     Average SM Active Cycles         cycle       106.05
#     Total SM Elapsed Cycles          cycle       88,920
#     Average SMSP Active Cycles       cycle       102.73
#     Total SMSP Elapsed Cycles        cycle      355,680
#     -------------------------- ----------- ------------
