# %% [markdown]
# ### **CUDA**
# Below is an example that runs native CUDA code.
#
# 1.   We investigate the CUDA version, drivers and the avaiable GPU with nvidia-smi and nvcc-version
# 2.   We use the IPython magic command "%%writefile filename" to save a *.cu program
# 3.   We then compile and run the *.cu program with nvcc

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Mon Dec  8 15:08:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# ...

# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             46 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      2
#   On-line CPU(s) list:       0,1
# Vendor ID:                   GenuineIntel
#   Model name:                Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:              6
#     Model:                   79
#     Thread(s) per core:      2
#     Core(s) per socket:      1
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4399.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ss h
#                              t syscall nx pdpe1gb rdtscp lm constant_tsc rep_goo
#                              d nopl xtopology nonstop_tsc cpuid tsc_known_freq p
# ...

# %%
# !git clone https://github.com/rishivijayv/DD2360-GPU.git files
# Out:
# fatal: destination path 'files' already exists and is not an empty directory.

# %% [markdown]
# ## We compile the saved cuda code using nvcc compiler

# %%
# !cd files/a3/bonus/code/iPIC3D-mini/ && make
# !cd files/a3/bonus/code/iPIC3D-mini/bin/ && ./miniPIC.out ../inputfiles/GEM_2D.inp
# !cd files/a3/bonus/code/iPIC3D-mini/ && make clean
# Out:
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall -DUSE_CPU src/sputniPIC.cpp -c -o src/sputniPIC.o
# In file included from src/sputniPIC.cpp:25:
# ./include/IC.h: In function ‘void initGEM(parameters*, grid*, EMfield*, EMfield_aux*, particles*, interpDensSpecies*)’:
# ./include/IC.h:82:25: warning: unused variable ‘sign’ [-Wunused-variable]
#    82 |     double prob, theta, sign;
#       |                         ^~~~
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall -DUSE_CPU src/EMfield.cpp -c -o src/EMfield.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall -DUSE_CPU src/Particles_aux.cpp -c -o src/Particles_aux.o
# src/Particles_aux.cpp: In function ‘void particle_aux_allocate(particles*, particles_aux*, int)’:
# src/Particles_aux.cpp:14:10: warning: unused variable ‘npmax’ [-Wunused-variable]
#    14 |     long npmax = part->npmax;
#       |          ^~~~~
# [ -d src ] || mkdir src
# ...

# %%
# !cd files/a3/bonus/code/iPIC3D-mini/ && make gpu
# !cd files/a3/bonus/code/iPIC3D-mini/bin/ && ./miniPIC.out ../inputfiles/GEM_2D.inp
# !cd files/a3/bonus/code/iPIC3D-mini/ && make clean
# Out:
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall -DUSE_GPU src/sputniPIC.cpp -c -o src/sputniPIC.o
# In file included from src/sputniPIC.cpp:25:
# ./include/IC.h: In function ‘void initGEM(parameters*, grid*, EMfield*, EMfield_aux*, particles*, interpDensSpecies*)’:
# ./include/IC.h:82:25: warning: unused variable ‘sign’ [-Wunused-variable]
#    82 |     double prob, theta, sign;
#       |                         ^~~~
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall -DUSE_GPU src/EMfield.cpp -c -o src/EMfield.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall -DUSE_GPU src/Particles_aux.cpp -c -o src/Particles_aux.o
# src/Particles_aux.cpp: In function ‘void particle_aux_allocate(particles*, particles_aux*, int)’:
# src/Particles_aux.cpp:14:10: warning: unused variable ‘npmax’ [-Wunused-variable]
#    14 |     long npmax = part->npmax;
#       |          ^~~~~
# [ -d src ] || mkdir src
# ...
