# %% [markdown]
# # Compiling & Logistics

# %%
# !nvidia-smi
# Out:
# Sun Nov 30 17:32:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !make
# Out:
# nvcc -arch=sm_75 -o vecAdd vecAddKernel.cu

# %% [markdown]
# # Running the `nvprof` profiling

# %%
# !/usr/local/cuda-12.5/bin/nvprof --output-profile vector_addition_streams.nvvp -f ./vecAdd 1024000 10240 0 0
# Out:
# ==629== NVPROF is profiling process 629, command: ./vecAdd 1024000 10240 0 0
# streams: 3.798008 ms
# ==629== Generated result file: /content/vector_addition_streams.nvvp
