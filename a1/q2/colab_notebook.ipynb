# %% [markdown]
# # Compiling the `vecAdd` Code

# %%
# !make
# Out:
# nvcc -arch=sm_75 -o vecAdd vecAddKernel.cu

# %% [markdown]
# # Checking NVIDIA GPU Information

# %%
# !nvidia-smi
# Out:
# Sun Nov  9 15:18:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # Achieved Occupancy for N=512

# %%
# !ncu ./vecAdd 512 0
# Out:
# ==PROF== Connected to process 469 (/content/vecAdd)
# ==PROF== Profiling "addGpu" - 0: 0%....50%....100% - 9 passes
# host_to_device: 0.000060 s
# kernel_exec: 0.632345 s
# device_to_host: 0.000067 s
# ==PROF== Disconnected from process 469
# [469] vecAdd@127.0.0.1
#   addGpu(double *, double *, double *, int) (1, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.92
#     SM Frequency                    Mhz       578.76
#     Elapsed Cycles                cycle        2,649
#     Memory Throughput                 %         0.88
#     DRAM Throughput                   %         0.86
#     Duration                         us         4.58
#     L1/TEX Cache Throughput           %        24.98
# ...

# %% [markdown]
# # Achieved Occupancy for N=263149

# %%
# !ncu ./vecAdd 263149 0
# Out:
# ==PROF== Connected to process 536 (/content/vecAdd)
# ==PROF== Profiling "addGpu" - 0: 0%....50%....100% - 9 passes
# host_to_device: 0.000944 s
# kernel_exec: 0.450515 s
# device_to_host: 0.007346 s
# ==PROF== Disconnected from process 536
# [536] vecAdd@127.0.0.1
#   addGpu(double *, double *, double *, int) (257, 1, 1)x(1024, 1, 1), Context 1, Stream 7, Device 0, CC 7.5
#     Section: GPU Speed Of Light Throughput
#     ----------------------- ----------- ------------
#     Metric Name             Metric Unit Metric Value
#     ----------------------- ----------- ------------
#     DRAM Frequency                  Ghz         4.57
#     SM Frequency                    Mhz       583.56
#     Elapsed Cycles                cycle       15,541
#     Memory Throughput                 %        77.27
#     DRAM Throughput                   %        77.27
#     Duration                         us        26.62
#     L1/TEX Cache Throughput           %        29.82
# ...

# %% [markdown]
# # Getting Data for Stacked Bar Chart

# %%
# !python3 run_experiments.py
# Out:
# Running for size: 524288
# Run 0
# Run 1
# Run 2
# Averages: host_to_device=0.0014316666666666668s, kernel_exec=0.00026233333333333333s, device_to_host=0.0047413333333333335s
#
# ---------------
# Running for size: 1048576
# Run 0
# Run 1
# Run 2
# Averages: host_to_device=0.003879s, kernel_exec=0.0003063333333333333s, device_to_host=0.010796333333333333s
#
# ---------------
# Running for size: 2097152
# Run 0
# Run 1
# Run 2
# Averages: host_to_device=0.007087666666666667s, kernel_exec=0.00043533333333333336s, device_to_host=0.020581666666666668s
#
# ---------------
# Running for size: 4194304
# Run 0
# Run 1
# Run 2
# Averages: host_to_device=0.011266333333333331s, kernel_exec=0.0006056666666666667s, device_to_host=0.03392066666666666s
#
# ---------------
# Running for size: 8388608
# Run 0
# Run 1
# Run 2
# Averages: host_to_device=0.021427666666666668s, kernel_exec=0.0009853333333333333s, device_to_host=0.06826966666666667s
#
# ---------------
# Running for size: 16777216
# ...
